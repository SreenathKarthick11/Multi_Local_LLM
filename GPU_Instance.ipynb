# %%
# !apt-get update -qq
# !apt-get install -y zstd -qq

# !curl -fsSL https://ollama.com/install.sh | sh

import os
import subprocess

os.environ["OLLAMA_HOST"] = "0.0.0.0:11434"

subprocess.Popen(
    ["ollama", "serve"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL
)

print("Ollama started")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Ollama started

# %%
# !ollama pull qwen2.5:3b

# !pip install -q pyngrok

from pyngrok import ngrok

ngrok.set_auth_token("YOUR_NGROK_TOKEN")

tunnel = ngrok.connect(11434)

print("Public URL:")
print(tunnel.public_url)
# Out:
# Public URL:
# https://unsaid-joylessly-remake.ngrok-free.dev

# %%
# !curl http://127.0.0.1:11434/api/tags
# Out:
# {"models":[{"name":"qwen2.5:3b","model":"qwen2.5:3b","modified_at":"2026-06-16T13:47:49.004142296Z","size":1929912432,"digest":"357c53fb659c5076de1d65ccb0b397446227b71a42be9d1603d46168015c9e4b","details":{"parent_model":"","format":"gguf","family":"qwen2","families":["qwen2"],"parameter_size":"3.1B","quantization_level":"Q4_K_M","context_length":32768,"embedding_length":2048},"capabilities":["completion","tools"]}]}

# %%
# !curl https://unsaid-joylessly-remake.ngrok-free.dev/api/tags
# Out:
# {"models":[{"name":"qwen2.5:3b","model":"qwen2.5:3b","modified_at":"2026-06-16T13:47:49.004142296Z","size":1929912432,"digest":"357c53fb659c5076de1d65ccb0b397446227b71a42be9d1603d46168015c9e4b","details":{"parent_model":"","format":"gguf","family":"qwen2","families":["qwen2"],"parameter_size":"3.1B","quantization_level":"Q4_K_M","context_length":32768,"embedding_length":2048},"capabilities":["completion","tools"]}]}

# %% [markdown]
# DEBUG

# %%
# !pkill ollama

# %%
# !ss -tulpn | grep 11434
